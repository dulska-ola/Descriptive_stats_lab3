# %% [raw]
# {
#  "cells": [
#   {
#    "metadata": {},
#    "cell_type": "code",
#    "source": "",
#    "id": "395936bce610d108",
#    "outputs": [],
#    "execution_count": null
#   },
#   {
#    "metadata": {},
#    "cell_type": "markdown",
#    "source": [
#     "<img src=\"data:image/png;base64,...\" class=\"bi x0 y0 w1 h1\" />\n",
#     "\n",
#     "{\n",
#     "\n",
#     "\"cells\":<span class=\"_ _0\"></span> \\[\n",
#     "\n",
#     "<span class=\"ls1\">{ </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"cel<span class=\"_ _0\"></span>l_type\":<span class=\"_ _0\"></span> \"markdow<span class=\"_ _0\"></span>n\", </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"met<span class=\"_ _0\"></span>adata\": <span class=\"_ _0\"></span>{}, </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"sou<span class=\"_ _0\"></span>rce\": \\[<span class=\"_ _0\"></span> </span>\n",
#     "\n",
#     "\"# La<span class=\"_ _0\"></span>boratory<span class=\"_ _0\"></span> 3 - Movi<span class=\"_ _0\"></span>ng avera<span class=\"_ _0\"></span>ge conver<span class=\"_ _0\"></span>gence di<span class=\"_ _0\"></span>vergen<span class=\"_ _0\"></span>ce (MACD)\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "<span class=\"ff2\">\"####<span class=\"_ _0\"></span> dr hab.<span class=\"_ _0\"></span> inż. Grz<span class=\"_ _0\"></span>egorz Fo<span class=\"_ _0\"></span>tyga, p<span class=\"_ _0\"></span>rof. PG<span class=\"ff1\">\\n\"<span class=\"_ _0\"></span>, </span></span>\n",
#     "\n",
#     "\"\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"The <span class=\"_ _0\"></span>goal of <span class=\"_ _0\"></span>this lab <span class=\"_ _0\"></span>is to im<span class=\"_ _0\"></span>plement o<span class=\"_ _0\"></span>ne of th<span class=\"_ _0\"></span>e most po<span class=\"_ _0\"></span>pular\n",
#     "\n",
#     "indicator<span class=\"_ _0\"></span>s used b<span class=\"_ _0\"></span>y the sto<span class=\"_ _0\"></span>ck bro<span class=\"_ _0\"></span>kers - MACD. <span class=\"_ _0\"></span>It can<span class=\"_ _0\"></span> be used <span class=\"_ _0\"></span>to analy<span class=\"_ _0\"></span>ze\n",
#     "\n",
#     "the trend<span class=\"_ _0\"></span>s and to<span class=\"_ _0\"></span> determin<span class=\"_ _0\"></span>e the <span class=\"_ _0\"></span>best buy <span class=\"_ _0\"></span>/ sell m<span class=\"_ _0\"></span>oments a<span class=\"_ _0\"></span>t the sto<span class=\"_ _0\"></span>ck\n",
#     "\n",
#     "market. Y<span class=\"_ _0\"></span>ou will <span class=\"_ _0\"></span>test that<span class=\"_ _0\"></span> tool <span class=\"_ _0\"></span>on the WI<span class=\"_ _0\"></span>G20 hist<span class=\"_ _0\"></span>orical d<span class=\"_ _0\"></span>ata. \"\n",
#     "\n",
#     "<span class=\"ls1\">\\] </span>\n",
#     "\n",
#     "<span class=\"ls2 ws0\">},</span><span class=\"ls1\"> </span>\n",
#     "\n",
#     "<span class=\"ls1\">{ </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"cel<span class=\"_ _0\"></span>l_type\":<span class=\"_ _0\"></span> \"markdow<span class=\"_ _0\"></span>n\", </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"met<span class=\"_ _0\"></span>adata\": <span class=\"_ _0\"></span>{}, </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"sou<span class=\"_ _0\"></span>rce\": \\[<span class=\"_ _0\"></span> </span>\n",
#     "\n",
#     "\"## 1<span class=\"_ _0\"></span> Introdu<span class=\"_ _0\"></span>ction - MAC<span class=\"_ _0\"></span>D indi<span class=\"_ _0\"></span>cator\\n\",\n",
#     "\n",
#     "\"\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"Movi<span class=\"_ _0\"></span>ng avera<span class=\"_ _0\"></span>ge conver<span class=\"_ _0\"></span>gence di<span class=\"_ _0\"></span>vergenc<span class=\"_ _0\"></span>e (MACD)<span class=\"_ _0\"></span> is one <span class=\"_ _0\"></span>of the si<span class=\"_ _0\"></span>mplest<span class=\"_ _0\"></span>\n",
#     "\n",
#     "and most <span class=\"_ _0\"></span>effectiv<span class=\"_ _0\"></span>e trend-fol<span class=\"_ _0\"></span>lowing<span class=\"_ _0\"></span> indicato<span class=\"_ _0\"></span>rs used <span class=\"_ _0\"></span>in techni<span class=\"_ _0\"></span>cal analys<span class=\"_ _0\"></span>is\n",
#     "\n",
#     "of stock <span class=\"_ _0\"></span>prices. <span class=\"_ _0\"></span>As the na<span class=\"_ _0\"></span>me sug<span class=\"_ _0\"></span>gests, th<span class=\"_ _0\"></span>e moving<span class=\"_ _0\"></span> average<span class=\"_ _0\"></span> converge<span class=\"_ _0\"></span>nce\n",
#     "\n",
#     "divergenc<span class=\"_ _0\"></span>e tool i<span class=\"_ _0\"></span>s a compa<span class=\"_ _0\"></span>rison <span class=\"_ _0\"></span>of the re<span class=\"_ _0\"></span>lationsh<span class=\"_ _0\"></span>ip betwe<span class=\"_ _0\"></span>en the tw<span class=\"_ _0\"></span>o\n",
#     "\n",
#     "moving av<span class=\"_ _0\"></span>erage li<span class=\"_ _0\"></span>nes of a <span class=\"_ _0\"></span>histor<span class=\"_ _0\"></span>ical pric<span class=\"_ _0\"></span>e data.\\n\"<span class=\"_ _0\"></span>,\n",
#     "\n",
#     "\"\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"Spec<span class=\"_ _0\"></span>ifically<span class=\"_ _0\"></span>, the fir<span class=\"_ _0\"></span>st line <span class=\"_ _0\"></span>of the <span class=\"_ _0\"></span>two-line i<span class=\"_ _0\"></span>ndicator <span class=\"_ _0\"></span>is the\n",
#     "\n",
#     "differenc<span class=\"_ _0\"></span>e betwee<span class=\"_ _0\"></span>n the val<span class=\"_ _0\"></span>ues of<span class=\"_ _0\"></span> two movi<span class=\"_ _0\"></span>ng avera<span class=\"_ _0\"></span>ges (exp<span class=\"_ _0\"></span>lained in<span class=\"_ _0\"></span>\n",
#     "\n",
#     "section 2<span class=\"_ _0\"></span>), and i<span class=\"_ _0\"></span>s conside<span class=\"_ _0\"></span>red th<span class=\"_ _0\"></span>e MACD li<span class=\"_ _0\"></span>ne. The <span class=\"_ _0\"></span>second l<span class=\"_ _0\"></span>ine (call<span class=\"_ _0\"></span>ed a\n",
#     "\n",
#     "SIGNAL) i<span class=\"_ _0\"></span>s a movi<span class=\"_ _0\"></span>ng averag<span class=\"_ _0\"></span>e of t<span class=\"_ _0\"></span>he MACD l<span class=\"_ _0\"></span>ine. Int<span class=\"_ _0\"></span>ersectio<span class=\"_ _0\"></span>n/crossin<span class=\"_ _0\"></span>g of\n",
#     "\n",
#     "the MACD <span class=\"_ _0\"></span>and SIGN<span class=\"_ _0\"></span>AL lines ar<span class=\"_ _0\"></span>e ofte<span class=\"_ _0\"></span>n seen as<span class=\"_ _0\"></span> buy and<span class=\"_ _0\"></span> sell mom<span class=\"_ _0\"></span>ents (<span class=\"_ _0\"></span>see\n",
#     "\n",
#     "Fig. 1). <span class=\"_ _0\"></span>Both lin<span class=\"_ _0\"></span>es are ce<span class=\"_ _0\"></span>ntered<span class=\"_ _0\"></span> on a zer<span class=\"_ _0\"></span>o line, <span class=\"_ _0\"></span>and will<span class=\"_ _0\"></span> travel a<span class=\"_ _0\"></span>bove\n",
#     "\n",
#     "and below<span class=\"_ _0\"></span> that le<span class=\"_ _0\"></span>vel depen<span class=\"_ _0\"></span>ding o<span class=\"_ _0\"></span>n the str<span class=\"_ _0\"></span>ength an<span class=\"_ _0\"></span>d length<span class=\"_ _0\"></span> of a tre<span class=\"_ _0\"></span>nd.\\n\",\n",
#     "\n",
#     "\"\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"\\![Fi<span class=\"_ _0\"></span>gure 1\\](<span class=\"_ _0\"></span>macd_exam<span class=\"_ _0\"></span>ple_plot<span class=\"_ _0\"></span>.png \\\\MACD<span class=\"_ _0\"></span> examp<span class=\"_ _0\"></span>le\\\\<span class=\"ls2 ws0\">\")</span><span class=\"ws1\">\\\\<span class=\"ls0 ws2\">n\"</span></span>\n",
#     "\n",
#     "<span class=\"ls1\">\\] </span>\n",
#     "\n",
#     "<span class=\"ls2 ws0\">},</span><span class=\"ls1\"> </span>\n",
#     "\n",
#     "<span class=\"ls1\">{ </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"cel<span class=\"_ _0\"></span>l_type\":<span class=\"_ _0\"></span> \"markdow<span class=\"_ _0\"></span>n\", </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"met<span class=\"_ _0\"></span>adata\": <span class=\"_ _0\"></span>{}, </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"sou<span class=\"_ _0\"></span>rce\": \\[<span class=\"_ _0\"></span> </span>\n",
#     "\n",
#     "<span class=\"ff2\">\"Exam<span class=\"_ _0\"></span>ple: let<span class=\"_ _0\"></span>’s assume<span class=\"_ _0\"></span>, we hav<span class=\"_ _0\"></span>e the s<span class=\"_ _0\"></span>tock pri<span class=\"_ _0\"></span>ces from<span class=\"_ _0\"></span> last 30 <span class=\"_ _0\"></span>days. </span>\n",
#     "\n",
#     "The goal <span class=\"_ _0\"></span>is to pr<span class=\"_ _0\"></span>edict bas<span class=\"_ _0\"></span>ing on<span class=\"_ _0\"></span> that dat<span class=\"_ _0\"></span>a the to<span class=\"_ _0\"></span>morrow’s<span class=\"_ _0\"></span> stock pr<span class=\"_ _0\"></span>ice,\n",
#     "\n",
#     "using the<span class=\"_ _0\"></span> technic<span class=\"_ _0\"></span>al analys<span class=\"_ _0\"></span>is tools<span class=\"_ _0\"></span>, such as<span class=\"_ _0\"></span> MACD.<span class=\"_ _0\"></span> Or to p<span class=\"_ _0\"></span>redict wh<span class=\"_ _0\"></span>en the\n",
#     "\n",
#     "increasin<span class=\"_ _0\"></span>g/decrea<span class=\"_ _0\"></span>sing tren<span class=\"_ _0\"></span>d will<span class=\"_ _0\"></span> change. <span class=\"_ _0\"></span>In other<span class=\"_ _0\"></span> words, <span class=\"_ _0\"></span>to determ<span class=\"_ _0\"></span>ine th<span class=\"_ _0\"></span>e\n",
#     "\n",
#     "best mome<span class=\"_ _0\"></span>nts to m<span class=\"_ _0\"></span>ake buyin<span class=\"_ _0\"></span>g / se<span class=\"_ _0\"></span>lling dec<span class=\"_ _0\"></span>isions.\\\\<span class=\"ls0 ws2\">n\"<span class=\"_ _0\"></span><span class=\"ls1 ws3\"> </span></span>\n",
#     "\n",
#     "<span class=\"ls1\">\\] </span>\n",
#     "\n",
#     "<span class=\"ls2 ws0\">},</span><span class=\"ls1\"> </span>\n",
#     "\n",
#     "<span class=\"ls1\">{ </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"cel<span class=\"_ _0\"></span>l_type\":<span class=\"_ _0\"></span> \"markdow<span class=\"_ _0\"></span>n\", </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"met<span class=\"_ _0\"></span>adata\": <span class=\"_ _0\"></span>{}, </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"sou<span class=\"_ _0\"></span>rce\": \\[<span class=\"_ _0\"></span> </span>\n",
#     "\n",
#     "<img src=\"data:image/png;base64,...\" class=\"bi x0 y0 w1 h1\" />\n",
#     "\n",
#     "\"## 2<span class=\"_ _0\"></span> Arithme<span class=\"_ _0\"></span>tic avera<span class=\"_ _0\"></span>ge\\n\",\n",
#     "\n",
#     "\"\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"Aver<span class=\"_ _0\"></span>age - th<span class=\"_ _0\"></span>e simples<span class=\"_ _0\"></span>t and mo<span class=\"_ _0\"></span>st common<span class=\"_ _0\"></span>ly use<span class=\"_ _0\"></span>d averag<span class=\"_ _0\"></span>e is the\n",
#     "\n",
#     "arithmeti<span class=\"_ _0\"></span>c one: s<span class=\"_ _0\"></span>um of a c<span class=\"_ _0\"></span>ollect<span class=\"_ _0\"></span>ion of pr<span class=\"_ _0\"></span>ices div<span class=\"_ _0\"></span>ided by <span class=\"_ _0\"></span>the numbe<span class=\"_ _0\"></span>r of\n",
#     "\n",
#     "prices in<span class=\"_ _0\"></span> the col<span class=\"_ _0\"></span>lection.\\n\"<span class=\"_ _0\"></span>,\n",
#     "\n",
#     "\"\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"Task<span class=\"_ _0\"></span>s: \\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"1) l<span class=\"_ _0\"></span>oad \\*dat<span class=\"_ _0\"></span>a_10_days<span class=\"_ _0\"></span>.txt\\*\\n\"<span class=\"_ _0\"></span>,\n",
#     "\n",
#     "\"2) p<span class=\"_ _0\"></span>lot it u<span class=\"_ _0\"></span>sing plt.<span class=\"_ _0\"></span>plot() f<span class=\"_ _0\"></span>unction<span class=\"_ _0\"></span> \\n\",\n",
#     "\n",
#     "\"3) C<span class=\"_ _0\"></span>ompute t<span class=\"_ _0\"></span>he averag<span class=\"_ _0\"></span>e value <span class=\"_ _0\"></span>of the <span class=\"_ _0\"></span>data usi<span class=\"_ _0\"></span>ng 2 met<span class=\"_ _0\"></span>hods: \\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\" <span class=\"_ _0\"></span>\\* direct<span class=\"_ _0\"></span> implemen<span class=\"_ _0\"></span>tation o<span class=\"_ _0\"></span>f arith<span class=\"_ _0\"></span>metic me<span class=\"_ _0\"></span>an (usin<span class=\"_ _0\"></span>g eg. \\*fo<span class=\"_ _0\"></span>r\\*\n",
#     "\n",
#     "loop)\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\" <span class=\"_ _0\"></span>\\* \\*np.me<span class=\"_ _0\"></span>an()\\*\\n\",\n",
#     "\n",
#     "\" <span class=\"_ _0\"></span>\\n\",\n",
#     "\n",
#     "\" <span class=\"_ _0\"></span>Compare <span class=\"_ _0\"></span>both resu<span class=\"_ _0\"></span>lts. \"\n",
#     "\n",
#     "<span class=\"ls1\">\\] </span>\n",
#     "\n",
#     "<span class=\"ls2 ws0\">},</span><span class=\"ls1\"> </span>\n",
#     "\n",
#     "<span class=\"ls1\">{ </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"cel<span class=\"_ _0\"></span>l_type\":<span class=\"_ _0\"></span> \"code\",<span class=\"_ _0\"></span> </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"exe<span class=\"_ _0\"></span>cution_c<span class=\"_ _0\"></span>ount\": nu<span class=\"_ _0\"></span>ll, </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"met<span class=\"_ _0\"></span>adata\": <span class=\"_ _0\"></span>{}, </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"out<span class=\"_ _0\"></span>puts\": \\[<span class=\"_ _0\"></span>\\], </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"sou<span class=\"_ _0\"></span>rce\": \\[<span class=\"_ _0\"></span> </span>\n",
#     "\n",
#     "\"impo<span class=\"_ _0\"></span>rt numpy<span class=\"_ _0\"></span> as np\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"impo<span class=\"_ _0\"></span>rt matpl<span class=\"_ _0\"></span>otlib.pyp<span class=\"_ _0\"></span>lot as p<span class=\"_ _0\"></span><span class=\"ls0 ws2\">lt<span class=\"ls1 ws3\">\\n\", </span></span>\n",
#     "\n",
#     "\"\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"file<span class=\"_ _0\"></span>\\_path = <span class=\"_ _0\"></span>'data_10\\_<span class=\"_ _0\"></span>days.txt<span class=\"_ _0\"></span>'\\n\",\n",
#     "\n",
#     "\"data<span class=\"_ _0\"></span>\\_10_days<span class=\"_ _0\"></span> = np.loa<span class=\"_ _0\"></span>dtxt(fil<span class=\"_ _0\"></span>e_path,<span class=\"_ _0\"></span> delimit<span class=\"_ _0\"></span>er=',', <span class=\"_ _0\"></span>dtype=flo<span class=\"_ _0\"></span>at)\\n\",\n",
#     "\n",
#     "\"plt.<span class=\"_ _0\"></span>plot(dat<span class=\"_ _0\"></span>a_10_days<span class=\"_ _0\"></span>,'o')\\n\"<span class=\"_ _0\"></span>,\n",
#     "\n",
#     "\"\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"# yo<span class=\"_ _0\"></span>ur code\"<span class=\"_ _0\"></span>\n",
#     "\n",
#     "<span class=\"ls1\">\\] </span>\n",
#     "\n",
#     "<span class=\"ls2 ws0\">},</span><span class=\"ls1\"> </span>\n",
#     "\n",
#     "<span class=\"ls1\">{ </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"cel<span class=\"_ _0\"></span>l_type\":<span class=\"_ _0\"></span> \"markdow<span class=\"_ _0\"></span>n\", </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"met<span class=\"_ _0\"></span>adata\": <span class=\"_ _0\"></span>{}, </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"sou<span class=\"_ _0\"></span>rce\": \\[<span class=\"_ _0\"></span> </span>\n",
#     "\n",
#     "\"## 3<span class=\"_ _0\"></span> Exponen<span class=\"_ _0\"></span>tial (wei<span class=\"_ _0\"></span>ghted) a<span class=\"_ _0\"></span>verage\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"Expo<span class=\"_ _0\"></span>nential <span class=\"_ _0\"></span>(weighted<span class=\"_ _0\"></span>) averag<span class=\"_ _0\"></span>e means<span class=\"_ _0\"></span> that we<span class=\"_ _0\"></span> want to<span class=\"_ _0\"></span> put more<span class=\"_ _0\"></span> weigh<span class=\"_ _0\"></span>t\n",
#     "\n",
#     "on the pr<span class=\"_ _0\"></span>ices of <span class=\"_ _0\"></span>the most <span class=\"_ _0\"></span>recent<span class=\"_ _0\"></span> days and<span class=\"_ _0\"></span> less we<span class=\"_ _0\"></span>ight on <span class=\"_ _0\"></span>the old p<span class=\"_ _0\"></span>rices.<span class=\"_ _0\"></span>\n",
#     "\n",
#     "The weigh<span class=\"_ _0\"></span>ts in ou<span class=\"_ _0\"></span>r case de<span class=\"_ _0\"></span>crease<span class=\"_ _0\"></span> exponentia<span class=\"_ _0\"></span>lly.\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"\\* \\$E<span class=\"_ _0\"></span>MA_N = \\\\<span class=\"_ _0\"></span>\\dfrac{p\\_<span class=\"_ _0\"></span>0 + (1-\\\\<span class=\"_ _0\"></span>\\alpha)p\\_<span class=\"_ _0\"></span>1 + (1-\\\\<span class=\"_ _0\"></span>\\alpha)^2<span class=\"_ _0\"></span>p_2 + ..<span class=\"_ _0\"></span>. +\n",
#     "\n",
#     "(1<span class=\"ls1 ws3\">-\\\\alph<span class=\"_ _0\"></span>a)^{n}<span class=\"_ _0\"></span> p\\_{n}}{1<span class=\"_ _0\"></span> + (1-\\\\al<span class=\"_ _0\"></span>pha) + (1<span class=\"_ _0\"></span>-\\\\alpha<span class=\"_ _0\"></span>)^2 + <span class=\"_ _0\"></span>... + (1-</span>\n",
#     "\n",
#     "\\\\alpha)^<span class=\"_ _0\"></span>{n}}\\$\\n\"<span class=\"_ _0\"></span>,\n",
#     "\n",
#     "\"\\* \\$p<span class=\"_ _0\"></span>\\_i\\$ is t<span class=\"_ _0\"></span>he stock <span class=\"_ _0\"></span>price fo<span class=\"_ _0\"></span>rm the <span class=\"_ _0\"></span>\\$i\\$-<span class=\"ff2\">th day<span class=\"_ _0\"></span>, \\$p_0\\$ i<span class=\"_ _0\"></span>s today’<span class=\"_ _0\"></span>s </span>\n",
#     "\n",
#     "price and<span class=\"_ _0\"></span> \\$p_n\\$ -<span class=\"_ _0\"></span> the pric<span class=\"_ _0\"></span>e from \\$<span class=\"_ _0\"></span>n\\$ days a<span class=\"_ _0\"></span>go\\n\",\n",
#     "\n",
#     "\"\\* \\$\\\\<span class=\"_ _0\"></span>\\alpha =<span class=\"_ _0\"></span> \\\\dfrac{<span class=\"_ _0\"></span>2}{n+1}\\$<span class=\"_ _0\"></span>\\n\",\n",
#     "\n",
#     "\"\\* \\$n<span class=\"_ _0\"></span>+1\\$ -<span class=\"ls2\"> </span>number o<span class=\"_ _0\"></span>f prices<span class=\"_ _0\"></span> (days<span class=\"_ _0\"></span>) taken i<span class=\"_ _0\"></span>nto acco<span class=\"_ _0\"></span>unt\\n\",\n",
#     "\n",
#     "\"\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"Task<span class=\"_ _0\"></span>s: \\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"4) C<span class=\"_ _0\"></span>ompute t<span class=\"_ _0\"></span>he expone<span class=\"_ _0\"></span>ntial av<span class=\"_ _0\"></span>erage v<span class=\"_ _0\"></span>alue of <span class=\"_ _0\"></span>the data<span class=\"_ _0\"></span> for \\*n=9<span class=\"_ _0\"></span>\\*. \\n<span class=\"ls2 ws0\">\",</span>\n",
#     "\n",
#     "<img src=\"data:image/png;base64,...\" class=\"bi x0 y0 w1 h1\" />\n",
#     "\n",
#     "\"5) D<span class=\"_ _0\"></span>efine \\*e<span class=\"_ _0\"></span>xp_avr()\\*<span class=\"_ _0\"></span> functio<span class=\"_ _0\"></span>n, whic<span class=\"_ _0\"></span>h comput<span class=\"_ _0\"></span>es expon<span class=\"_ _0\"></span>ential av<span class=\"_ _0\"></span>erage\n",
#     "\n",
#     "for speci<span class=\"_ _0\"></span>fied dat<span class=\"_ _0\"></span>a and \\*n\\*<span class=\"_ _0\"></span>\"\n",
#     "\n",
#     "<span class=\"ls1\">\\] </span>\n",
#     "\n",
#     "<span class=\"ls2 ws0\">},</span><span class=\"ls1\"> </span>\n",
#     "\n",
#     "<span class=\"ls1\">{ </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"cel<span class=\"_ _0\"></span>l_type\":<span class=\"_ _0\"></span> \"code\",<span class=\"_ _0\"></span> </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"exe<span class=\"_ _0\"></span>cution_c<span class=\"_ _0\"></span>ount\": nu<span class=\"_ _0\"></span>ll, </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"met<span class=\"_ _0\"></span>adata\": <span class=\"_ _0\"></span>{}, </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"out<span class=\"_ _0\"></span>puts\": \\[<span class=\"_ _0\"></span>\\], </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"sou<span class=\"_ _0\"></span>rce\": \\[<span class=\"_ _0\"></span> </span>\n",
#     "\n",
#     "\"# yo<span class=\"_ _0\"></span>ur code\"<span class=\"_ _0\"></span>\n",
#     "\n",
#     "<span class=\"ls1\">\\] </span>\n",
#     "\n",
#     "<span class=\"ls2 ws0\">},</span><span class=\"ls1\"> </span>\n",
#     "\n",
#     "<span class=\"ls1\">{ </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"cel<span class=\"_ _0\"></span>l_type\":<span class=\"_ _0\"></span> \"code\",<span class=\"_ _0\"></span> </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"exe<span class=\"_ _0\"></span>cution_c<span class=\"_ _0\"></span>ount\": nu<span class=\"_ _0\"></span>ll, </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"met<span class=\"_ _0\"></span>adata\": <span class=\"_ _0\"></span>{}, </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"out<span class=\"_ _0\"></span>puts\": \\[<span class=\"_ _0\"></span>\\], </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"sou<span class=\"_ _0\"></span>rce\": \\[<span class=\"_ _0\"></span> </span>\n",
#     "\n",
#     "\"# yo<span class=\"_ _0\"></span>ur code\"<span class=\"_ _0\"></span>\n",
#     "\n",
#     "<span class=\"ls1\">\\] </span>\n",
#     "\n",
#     "<span class=\"ls2 ws0\">},</span><span class=\"ls1\"> </span>\n",
#     "\n",
#     "<span class=\"ls1\">{ </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"cel<span class=\"_ _0\"></span>l_type\":<span class=\"_ _0\"></span> \"markdow<span class=\"_ _0\"></span>n\", </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"met<span class=\"_ _0\"></span>adata\": <span class=\"_ _0\"></span>{}, </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"sou<span class=\"_ _0\"></span>rce\": \\[<span class=\"_ _0\"></span> </span>\n",
#     "\n",
#     "\"## 4<span class=\"_ _0\"></span> Moving <span class=\"_ _0\"></span>average\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"<span class=\"ff2\">Let’<span class=\"_ _0\"></span>s assume<span class=\"_ _0\"></span>, we have<span class=\"_ _0\"></span> a full <span class=\"_ _0\"></span>data se<span class=\"_ _0\"></span>t, for e<span class=\"_ _0\"></span>xample o<span class=\"_ _0\"></span>pening st<span class=\"_ _0\"></span>ock </span>\n",
#     "\n",
#     "prices fr<span class=\"_ _0\"></span>om the w<span class=\"_ _0\"></span>hole last<span class=\"_ _0\"></span> year <span class=\"_ _0\"></span>(one pric<span class=\"_ _0\"></span>e a day)<span class=\"_ _0\"></span>. Common<span class=\"_ _0\"></span>ly, we ar<span class=\"_ _0\"></span>e\n",
#     "\n",
#     "intereste<span class=\"_ _0\"></span>d in cre<span class=\"_ _0\"></span>ating ser<span class=\"_ _0\"></span>ies of<span class=\"_ _0\"></span> averages<span class=\"_ _0\"></span> of diff<span class=\"_ _0\"></span>erent su<span class=\"_ _0\"></span>bsets of <span class=\"_ _0\"></span>that\n",
#     "\n",
#     "full data<span class=\"_ _0\"></span> set, fo<span class=\"_ _0\"></span>r example<span class=\"_ _0\"></span> the a<span class=\"_ _0\"></span>verages o<span class=\"_ _0\"></span>f the st<span class=\"_ _0\"></span>ock prices <span class=\"_ _0\"></span>from the<span class=\"_ _0\"></span> last\n",
#     "\n",
#     "10 days, <span class=\"_ _0\"></span>computed<span class=\"_ _0\"></span> everyday<span class=\"_ _0\"></span>. movi<span class=\"_ _0\"></span>ng means <span class=\"_ _0\"></span>that it <span class=\"_ _0\"></span>is appli<span class=\"_ _0\"></span>ed to sub<span class=\"_ _0\"></span>sequen<span class=\"_ _0\"></span>t\n",
#     "\n",
#     "data poin<span class=\"_ _0\"></span>ts.\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"Task<span class=\"_ _0\"></span>:\\n\",\n",
#     "\n",
#     "\"\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"6) L<span class=\"_ _0\"></span>oad \\*dat<span class=\"_ _0\"></span>a_1000_da<span class=\"_ _0\"></span>ys.txt\\* <span class=\"_ _0\"></span>file an<span class=\"_ _0\"></span>d comput<span class=\"_ _0\"></span>e expone<span class=\"_ _0\"></span>ntial mov<span class=\"_ _0\"></span>ing\n",
#     "\n",
#     "average u<span class=\"_ _0\"></span>sing \\*ex<span class=\"_ _0\"></span>p_avr()\\* <span class=\"_ _0\"></span>functi<span class=\"_ _0\"></span>on for \\*n=1<span class=\"_ _0\"></span>0\\* start<span class=\"_ _0\"></span>ing with <span class=\"_ _0\"></span>11-th day\n",
#     "\n",
#     "(\\$EMA\\_{10<span class=\"_ _0\"></span>}\\$)\"\n",
#     "\n",
#     "<span class=\"ls1\">\\] </span>\n",
#     "\n",
#     "<span class=\"ls2 ws0\">},</span><span class=\"ls1\"> </span>\n",
#     "\n",
#     "<span class=\"ls1\">{ </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"cel<span class=\"_ _0\"></span>l_type\":<span class=\"_ _0\"></span> \"code\",<span class=\"_ _0\"></span> </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"exe<span class=\"_ _0\"></span>cution_c<span class=\"_ _0\"></span>ount\": nu<span class=\"_ _0\"></span>ll, </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"met<span class=\"_ _0\"></span>adata\": <span class=\"_ _0\"></span>{}, </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"out<span class=\"_ _0\"></span>puts\": \\[<span class=\"_ _0\"></span>\\], </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"sou<span class=\"_ _0\"></span>rce\": \\[<span class=\"_ _0\"></span> </span>\n",
#     "\n",
#     "\"file<span class=\"_ _0\"></span>\\_path = <span class=\"_ _0\"></span>'data_100<span class=\"_ _0\"></span>0_days.t<span class=\"_ _0\"></span>xt'\\\\<span class=\"ls0 ws2\">n\",</span>\n",
#     "\n",
#     "\"data<span class=\"_ _0\"></span>\\_1000_da<span class=\"_ _0\"></span>ys = np.l<span class=\"_ _0\"></span>oadtxt(f<span class=\"_ _0\"></span>ile_path,<span class=\"_ _0\"></span> delimit<span class=\"_ _0\"></span>er=',',\n",
#     "\n",
#     "dtype=flo<span class=\"_ _0\"></span>at)\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"exp\\_<span class=\"_ _0\"></span>aver = n<span class=\"_ _0\"></span>p.zeros_l<span class=\"_ _0\"></span>ike(data<span class=\"_ _0\"></span>\\_1000_d<span class=\"_ _0\"></span>ays)\\n\",\n",
#     "\n",
#     "\"# yo<span class=\"_ _0\"></span>ur code\\\\<span class=\"_ _0\"></span><span class=\"ls0 ws2\">n\"<span class=\"ls1 ws3\"> </span></span>\n",
#     "\n",
#     "<span class=\"ls1\">\\] </span>\n",
#     "\n",
#     "<img src=\"data:image/png;base64,...\" class=\"bi x0 y0 w1 h1\" />\n",
#     "\n",
#     "<span class=\"ls2 ws0\">},</span><span class=\"ls1\"> </span>\n",
#     "\n",
#     "<span class=\"ls1\">{ </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"cel<span class=\"_ _0\"></span>l_type\":<span class=\"_ _0\"></span> \"markdow<span class=\"_ _0\"></span>n\", </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"met<span class=\"_ _0\"></span>adata\": <span class=\"_ _0\"></span>{}, </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"sou<span class=\"_ _0\"></span>rce\": \\[<span class=\"_ _0\"></span> </span>\n",
#     "\n",
#     "\"## 5<span class=\"_ _0\"></span>. MACD i<span class=\"_ _0\"></span>ndicator \\n<span class=\"_ _0\"></span>\",\n",
#     "\n",
#     "\"\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"MACD<span class=\"_ _0\"></span> and SIG<span class=\"_ _0\"></span>NAL are d<span class=\"_ _0\"></span>efined a<span class=\"_ _0\"></span>s follows<span class=\"_ _0\"></span>:\\n\",\n",
#     "\n",
#     "<span class=\"ff2\">\"1. M<span class=\"_ _0\"></span>ACD = EM<span class=\"_ _0\"></span>A12 − EMA<span class=\"_ _0\"></span>26, wher<span class=\"_ _0\"></span>e EMA12<span class=\"_ _0\"></span> and EMA<span class=\"_ _0\"></span>26 are c<span class=\"_ _0\"></span>omputed b<span class=\"_ _0\"></span>ased o<span class=\"_ _0\"></span>n </span>\n",
#     "\n",
#     "the stock<span class=\"_ _0\"></span> prices <span class=\"_ _0\"></span>data.\\n\",\n",
#     "\n",
#     "\"2. S<span class=\"_ _0\"></span>IGNAL = <span class=\"_ _0\"></span>EMA9 is c<span class=\"_ _0\"></span>omputed <span class=\"_ _0\"></span>based o<span class=\"_ _0\"></span>n MACD p<span class=\"_ _0\"></span>lot.\\n\",\n",
#     "\n",
#     "\"\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"Task<span class=\"_ _0\"></span>s:\\n\",\n",
#     "\n",
#     "\"\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"7) G<span class=\"_ _0\"></span>enerate <span class=\"_ _0\"></span>MACD and <span class=\"_ _0\"></span>SIGNAL f<span class=\"_ _0\"></span>or \\*data\\_<span class=\"_ _0\"></span>1000_d<span class=\"_ _0\"></span>ays.txt\\*\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"8) P<span class=\"_ _0\"></span>lot MACD<span class=\"_ _0\"></span> and SIGN<span class=\"_ _0\"></span>AL. Obse<span class=\"_ _0\"></span>rve the<span class=\"_ _0\"></span> correla<span class=\"_ _0\"></span>tion bet<span class=\"_ _0\"></span>ween\n",
#     "\n",
#     "data_1000<span class=\"_ _0\"></span>\\_days pl<span class=\"_ _0\"></span>ot and cr<span class=\"_ _0\"></span>oss se<span class=\"_ _0\"></span>ctions of<span class=\"_ _0\"></span> MACD an<span class=\"_ _0\"></span>d SIGNAL<span class=\"_ _0\"></span>. Use plt<span class=\"_ _0\"></span>.xlim(<span class=\"_ _0\"></span>)\n",
#     "\n",
#     "and plt.y<span class=\"_ _0\"></span>lim(). <span class=\"_ _0\"></span> \\\\<span class=\"ls0 ws2\">n\",</span>\n",
#     "\n",
#     "\"9) W<span class=\"_ _0\"></span>rite sho<span class=\"_ _0\"></span>rt commen<span class=\"_ _0\"></span>ts - can<span class=\"_ _0\"></span> you pred<span class=\"_ _0\"></span>ict the <span class=\"_ _0\"></span>future pr<span class=\"_ _0\"></span>ices usi<span class=\"_ _0\"></span>ng\n",
#     "\n",
#     "MACD indi<span class=\"_ _0\"></span>cator? \\\\<span class=\"_ _0\"></span>n\",\n",
#     "\n",
#     "\"10) <span class=\"_ _0\"></span>Save the<span class=\"_ _0\"></span> notebook<span class=\"_ _0\"></span> and upl<span class=\"_ _0\"></span>oad on <span class=\"_ _0\"></span>enauczan<span class=\"_ _0\"></span>ie cours<span class=\"_ _0\"></span>e site. \"\n",
#     "\n",
#     "<span class=\"ls1\">\\] </span>\n",
#     "\n",
#     "<span class=\"ls2 ws0\">},</span><span class=\"ls1\"> </span>\n",
#     "\n",
#     "<span class=\"ls1\">{ </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"cel<span class=\"_ _0\"></span>l_type\":<span class=\"_ _0\"></span> \"code\",<span class=\"_ _0\"></span> </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"exe<span class=\"_ _0\"></span>cution_c<span class=\"_ _0\"></span>ount\": nu<span class=\"_ _0\"></span>ll, </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"met<span class=\"_ _0\"></span>adata\": <span class=\"_ _0\"></span>{}, </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"out<span class=\"_ _0\"></span>puts\": \\[<span class=\"_ _0\"></span>\\], </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"sou<span class=\"_ _0\"></span>rce\": \\[<span class=\"_ _0\"></span> </span>\n",
#     "\n",
#     "\"exp\\_<span class=\"_ _0\"></span>aver12 =<span class=\"_ _0\"></span> np.zeros<span class=\"_ _0\"></span>\\_like(da<span class=\"_ _0\"></span>ta_1000_d<span class=\"_ _0\"></span>ays)\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"exp\\_<span class=\"_ _0\"></span>aver26 =<span class=\"_ _0\"></span> np.zeros<span class=\"_ _0\"></span>\\_like(da<span class=\"_ _0\"></span>ta_1000<span class=\"_ _0\"></span>\\_days)\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"sign<span class=\"_ _0\"></span>al = np.<span class=\"_ _0\"></span>zeros_lik<span class=\"_ _0\"></span>e(data_1<span class=\"_ _0\"></span>000_day<span class=\"_ _0\"></span>s)\\n\",\n",
#     "\n",
#     "\"\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"# yo<span class=\"_ _0\"></span>ur code\\\\<span class=\"_ _0\"></span>n\",\n",
#     "\n",
#     "\"\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"plt.<span class=\"_ _0\"></span>figure()<span class=\"_ _0\"></span>\\n\",\n",
#     "\n",
#     "\"plt.<span class=\"_ _0\"></span>plot(dat<span class=\"_ _0\"></span>a_1000_da<span class=\"_ _0\"></span>ys)\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"# pl<span class=\"_ _0\"></span>t.xlim(3<span class=\"_ _0\"></span>00, 400) <span class=\"_ _0\"></span> \\n\",\n",
#     "\n",
#     "\"plt.<span class=\"_ _0\"></span>grid()\\n<span class=\"_ _0\"></span>\",\n",
#     "\n",
#     "\"plt.<span class=\"_ _0\"></span>show()\\n<span class=\"_ _0\"></span>\",\n",
#     "\n",
#     "\"\\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"plt.<span class=\"_ _0\"></span>figure()<span class=\"_ _0\"></span>\\n\",\n",
#     "\n",
#     "\"plt.<span class=\"_ _0\"></span>plot(MAC<span class=\"_ _0\"></span>D) \\n\",\n",
#     "\n",
#     "\"plt.<span class=\"_ _0\"></span>plot(sig<span class=\"_ _0\"></span>nal) \\n\",<span class=\"_ _0\"></span>\n",
#     "\n",
#     "\"# pl<span class=\"_ _0\"></span>t.xlim(3<span class=\"_ _0\"></span>00, 400) <span class=\"_ _0\"></span> \\n\",\n",
#     "\n",
#     "\"plt.<span class=\"_ _0\"></span>grid()\\n<span class=\"_ _0\"></span>\",\n",
#     "\n",
#     "\"plt.<span class=\"_ _0\"></span>show()\"<span class=\"_ _0\"></span>\n",
#     "\n",
#     "<span class=\"ls1\">\\] </span>\n",
#     "\n",
#     "<span class=\"ls1\">} </span>\n",
#     "\n",
#     "<span class=\"ws2\">\\],</span><span class=\"ls1\"> </span>\n",
#     "\n",
#     "\"metadat<span class=\"_ _0\"></span>a\": {\n",
#     "\n",
#     "<span class=\"ls1\">\"kernel<span class=\"_ _0\"></span>spec\":<span class=\"_ _0\"></span> { </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"dis<span class=\"_ _0\"></span>play_nam<span class=\"_ _0\"></span>e\": \"Pyth<span class=\"_ _0\"></span>on 3\", </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"lan<span class=\"_ _0\"></span>guage\": <span class=\"_ _0\"></span>\"python\", </span>\n",
#     "\n",
#     "<img src=\"data:image/png;base64,...\" class=\"bi x0 y0 w1 h1\" />\n",
#     "\n",
#     "<span class=\"ls1\">\"nam<span class=\"_ _0\"></span>e\": \"pyt<span class=\"_ _0\"></span>hon3\" </span>\n",
#     "\n",
#     "<span class=\"ls2 ws0\">},</span><span class=\"ls1\"> </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"langua<span class=\"_ _0\"></span>ge_inf<span class=\"_ _0\"></span>o\": { </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"cod<span class=\"_ _0\"></span>emirror\\_<span class=\"_ _0\"></span>mode\": {<span class=\"_ _0\"></span> </span>\n",
#     "\n",
#     "\"name<span class=\"_ _0\"></span>\": \"ipyt<span class=\"_ _0\"></span>hon\",\n",
#     "\n",
#     "\"vers<span class=\"_ _0\"></span>ion\": 3<span class=\"_ _0\"></span>\n",
#     "\n",
#     "},<span class=\"ls1\"> </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"fil<span class=\"_ _0\"></span>e_extens<span class=\"_ _0\"></span>ion\": \".p<span class=\"_ _0\"></span>y\", </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"mim<span class=\"_ _0\"></span>etype\": <span class=\"_ _0\"></span>\"text/x-<span class=\"ls2 ws0\">py</span>thon\"<span class=\"_ _0\"></span>, </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"nam<span class=\"_ _0\"></span>e\": \"pyt<span class=\"_ _0\"></span>hon\", </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"nbc<span class=\"_ _0\"></span>onvert_e<span class=\"_ _0\"></span>xporter\":<span class=\"_ _0\"></span> \"python<span class=\"_ _0\"></span>\", </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"pyg<span class=\"_ _0\"></span>ments_le<span class=\"_ _0\"></span>xer\": \"ip<span class=\"_ _0\"></span>ython3\",<span class=\"_ _0\"></span> </span>\n",
#     "\n",
#     "<span class=\"ls1\">\"ver<span class=\"_ _0\"></span>sion\": \"<span class=\"_ _0\"></span>3.12.0\" </span>\n",
#     "\n",
#     "<span class=\"ls1\">} </span>\n",
#     "\n",
#     "<span class=\"ws2\">},</span><span class=\"ls1\"> </span>\n",
#     "\n",
#     "\"nbforma<span class=\"_ _0\"></span>t\": 4,\n",
#     "\n",
#     "\"nbforma<span class=\"_ _0\"></span>t_minor\"<span class=\"_ _0\"></span>: 2\n",
#     "\n",
#     "}\n",
#     "\n",
#     "![](data:image/png;base64,...)"
#    ],
#    "id": "8032ba8a62e39e89"
#   }
#  ],
#  "nbformat": 4,
#  "nbformat_minor": 5,
#  "metadata": {}
# }
